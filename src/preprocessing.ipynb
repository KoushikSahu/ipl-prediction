# %%
# basic python imports
from pathlib import Path
import pickle

# data science libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# scikit learn related imports
from sklearn import preprocessing

# %%
# configuration for the code
class config:
    start_date = '2018-01-01'
    columns = [
        'match_id',
        'venue',
        'innings',
        'ball',
        'batting_team',
        'bowling_team',
        'striker',
        'non_striker',
        'bowler',
        'runs_off_bat',
        'extras'
    ]

# %%
# path objects for easier reference in code
path = Path('../data/raw/')
data_path = Path('../data/raw/all_matches.csv')
dest_path = Path('../data/processed/')
pkl_path = Path('../bin/objs')

# %%
# loading data
df = pd.read_csv(data_path)
df.head()
# Out:
# /home/koushiksahu/miniconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    match_id   season  start_date                  venue  innings  ball  \
# 0    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.1
# 1    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.2
# 2    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.3
# 3    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.4
# 4    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.5
#
#             batting_team                 bowling_team      striker  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
#
#    non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# 0  BB McCullum  ...      1    NaN      NaN   NaN      1.0      NaN
# 1   SC Ganguly  ...      0    NaN      NaN   NaN      NaN      NaN
# 2   SC Ganguly  ...      1    1.0      NaN   NaN      NaN      NaN
# 3   SC Ganguly  ...      0    NaN      NaN   NaN      NaN      NaN
# 4   SC Ganguly  ...      0    NaN      NaN   NaN      NaN      NaN
#
#    wicket_type  player_dismissed other_wicket_type other_player_dismissed
# 0          NaN               NaN               NaN                    NaN
# 1          NaN               NaN               NaN                    NaN
# 2          NaN               NaN               NaN                    NaN
# 3          NaN               NaN               NaN                    NaN
# 4          NaN               NaN               NaN                    NaN
#
# [5 rows x 22 columns]

# %%
# converting match_id to datetime and then considering rows after config.start_date
df['start_date'] = pd.to_datetime(df['start_date'])
df = df[df['start_date']>=np.datetime64(config.start_date)].reset_index(drop=True)
df.head()
# Out:
#    match_id season start_date                   venue  innings  ball  \
# 0   1175356   2019 2019-03-23  MA Chidambaram Stadium        1   0.1
# 1   1175356   2019 2019-03-23  MA Chidambaram Stadium        1   0.2
# 2   1175356   2019 2019-03-23  MA Chidambaram Stadium        1   0.3
# 3   1175356   2019 2019-03-23  MA Chidambaram Stadium        1   0.4
# 4   1175356   2019 2019-03-23  MA Chidambaram Stadium        1   0.5
#
#                   batting_team         bowling_team   striker non_striker  \
# 0  Royal Challengers Bangalore  Chennai Super Kings   V Kohli    PA Patel
# 1  Royal Challengers Bangalore  Chennai Super Kings  PA Patel     V Kohli
# 2  Royal Challengers Bangalore  Chennai Super Kings  PA Patel     V Kohli
# 3  Royal Challengers Bangalore  Chennai Super Kings  PA Patel     V Kohli
# 4  Royal Challengers Bangalore  Chennai Super Kings  PA Patel     V Kohli
#
#    ... extras  wides  noballs  byes  legbyes  penalty  wicket_type  \
# 0  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 1  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 2  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 3  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 4  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
#
#    player_dismissed other_wicket_type other_player_dismissed
# 0               NaN               NaN                    NaN
# 1               NaN               NaN                    NaN
# 2               NaN               NaN                    NaN
# 3               NaN               NaN                    NaN
# 4               NaN               NaN                    NaN
#
# [5 rows x 22 columns]

# %%
# label encoding
venue_le = preprocessing.LabelEncoder()
team_le = preprocessing.LabelEncoder()
player_le = preprocessing.LabelEncoder()

# fitting label encoders
venue_le.fit(df['venue'].unique())
team_le.fit(df['batting_team'].unique())
player_le.fit(df['striker'].unique().tolist() + df['non_striker'].unique().tolist() + df['bowler'].unique().tolist())
# Out:
# LabelEncoder()

# %%
with open(pkl_path/'venue_le.pkl', 'wb') as f:
    pickle.dump(venue_le, f)
    
with open(pkl_path/'team_le.pkl', 'wb') as f:
    pickle.dump(team_le, f)

# %%
# taking only six overs and relavent columns now
df_sixovers = df[df['ball']<=5.6].reset_index(drop=True).loc[:, config.columns]
df_sixovers
# Out:
#        match_id                                     venue  innings  ball  \
# 0       1175356                    MA Chidambaram Stadium        1   0.1
# 1       1175356                    MA Chidambaram Stadium        1   0.2
# 2       1175356                    MA Chidambaram Stadium        1   0.3
# 3       1175356                    MA Chidambaram Stadium        1   0.4
# 4       1175356                    MA Chidambaram Stadium        1   0.5
# ...         ...                                       ...      ...   ...
# 13564   1254060  MA Chidambaram Stadium, Chepauk, Chennai        2   5.2
# 13565   1254060  MA Chidambaram Stadium, Chepauk, Chennai        2   5.3
# 13566   1254060  MA Chidambaram Stadium, Chepauk, Chennai        2   5.4
# 13567   1254060  MA Chidambaram Stadium, Chepauk, Chennai        2   5.5
# 13568   1254060  MA Chidambaram Stadium, Chepauk, Chennai        2   5.6
#
#                       batting_team           bowling_team      striker  \
# 0      Royal Challengers Bangalore    Chennai Super Kings      V Kohli
# 1      Royal Challengers Bangalore    Chennai Super Kings     PA Patel
# 2      Royal Challengers Bangalore    Chennai Super Kings     PA Patel
# 3      Royal Challengers Bangalore    Chennai Super Kings     PA Patel
# 4      Royal Challengers Bangalore    Chennai Super Kings     PA Patel
# ...                            ...                    ...          ...
# 13564          Sunrisers Hyderabad  Kolkata Knight Riders  JM Bairstow
# 13565          Sunrisers Hyderabad  Kolkata Knight Riders  JM Bairstow
# 13566          Sunrisers Hyderabad  Kolkata Knight Riders    MK Pandey
# 13567          Sunrisers Hyderabad  Kolkata Knight Riders    MK Pandey
# 13568          Sunrisers Hyderabad  Kolkata Knight Riders    MK Pandey
#
#        non_striker      bowler  runs_off_bat  extras
# 0         PA Patel   DL Chahar             1       0
# 1          V Kohli   DL Chahar             0       0
# 2          V Kohli   DL Chahar             0       0
# 3          V Kohli   DL Chahar             0       0
# 4          V Kohli   DL Chahar             4       0
# ...            ...         ...           ...     ...
# 13564    MK Pandey  PJ Cummins             0       0
# 13565    MK Pandey  PJ Cummins             1       0
# 13566  JM Bairstow  PJ Cummins             0       0
# 13567  JM Bairstow  PJ Cummins             0       0
# 13568  JM Bairstow  PJ Cummins             1       0
#
# [13569 rows x 11 columns]

# %%
# declaring dict to store new data that will be used for training
new_data = dict()
new_data['venue'] = []
new_data['batting_team'] = []
new_data['bowling_team'] = []
new_data['innings'] = []
new_data['score'] = []

# %%
# consider each match and make new df
for match_id, match_df in df_sixovers.groupby('match_id'):
    for teams, team_df in match_df.groupby(['batting_team', 'bowling_team']):
        new_data['venue'].append(team_df['venue'].values[0])
        new_data['batting_team'].append(teams[0])
        new_data['bowling_team'].append(teams[1])
        new_data['innings'].append(team_df['innings'].values[0])
        new_data['score'].append(sum(team_df['runs_off_bat'].values) + sum(team_df['extras'].values))

# %%
# declaring clean data csv
clean_df = pd.DataFrame(new_data)
clean_df.head()
# Out:
#                                           venue           batting_team  \
# 0                              Wankhede Stadium    Chennai Super Kings
# 1                              Wankhede Stadium         Mumbai Indians
# 2  Punjab Cricket Association IS Bindra Stadium       Delhi Daredevils
# 3  Punjab Cricket Association IS Bindra Stadium        Kings XI Punjab
# 4                                  Eden Gardens  Kolkata Knight Riders
#
#                   bowling_team  innings  score
# 0               Mumbai Indians        2     42
# 1          Chennai Super Kings        1     39
# 2              Kings XI Punjab        1     45
# 3             Delhi Daredevils        2     73
# 4  Royal Challengers Bangalore        2     67

# %%
# saving clean data
clean_df.to_csv(dest_path/'clean_data.csv', index=False)

# %%
# declaring training dataframe
train_df = clean_df
train_df['venue'] = venue_le.transform(train_df['venue'])
train_df['batting_team'] = team_le.transform(train_df['batting_team'])
train_df['bowling_team'] = team_le.transform(train_df['bowling_team'])
train_df.head()
# Out:
#    venue  batting_team  bowling_team  innings  score
# 0     14             0             5        2     42
# 1     14             5             0        1     39
# 2      9             2             3        1     45
# 3      9             3             2        2     73
# 4      3             4             7        2     67

# %%
# saving training dataframe
train_df.to_csv(dest_path/'train.csv', index=False)
